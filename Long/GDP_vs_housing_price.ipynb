# %%
import pandas as pd

# %%
home_df = pd.read_csv('../Source/Metro_Home_Values.csv')
home_df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName     2000-01-31  \
# 0    102001         0    United States    country       NaN  123951.733006
# 1    394913         1     New York, NY        msa        NY  219657.598399
# 2    753899         2  Los Angeles, CA        msa        CA  236649.976987
# 3    394463         3      Chicago, IL        msa        IL  159899.676257
# 4    394514         4       Dallas, TX        msa        TX  129057.198121
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...  \
# 0  124163.176264  124425.524492  124988.958362  125637.500450  ...
# 1  220586.011622  221519.660004  223407.993412  225353.501267  ...
# 2  237553.116159  238728.814647  241071.926563  243614.826354  ...
# 3  160054.921113  160340.806271  161051.946252  161901.787792  ...
# 4  129114.277857  129184.712729  129363.326656  129593.351700  ...
#
#       2023-10-31     2023-11-30     2023-12-31     2024-01-31     2024-02-29  \
# 0  355986.448327  356640.365507  357118.576760  357576.035711  358418.372959
# 1  656116.650291  658992.330717  662322.088290  665541.460972  669925.455906
# 2  978656.081035  988006.132016  993962.586203  994044.629696  990763.189872
# 3  328270.794339  329219.545752  329991.513159  330838.545303  332482.161364
# 4  380533.777024  380382.508383  380056.886976  380085.827764  380580.411239
#
#       2024-03-31     2024-04-30    2024-05-31    2024-06-30    2024-07-31
# 0  360011.602927  361969.362164  3.635033e+05  3.641659e+05  3.643848e+05
# 1  675684.524493  682290.159549  6.873056e+05  6.905686e+05  6.932481e+05
# 2  989599.749912  993777.833894  1.000601e+06  1.005222e+06  1.010107e+06
# 3  335195.288195  338356.149580  3.407269e+05  3.421063e+05  3.429366e+05
# 4  381762.207346  382759.281581  3.829150e+05  3.822440e+05  3.812958e+05
#
# [5 rows x 300 columns]

# %%
# Define the columns to keep:
# First five columns
columns_to_keep = home_df.columns[:5]

# Extract year from columns and identify columns for 2022, 2023, and 2024
def extract_year_from_column(col_name):
    try:
        return col_name.split('-')[0]  # Extract year from 'YYYY-MM-DD'
    except IndexError:
        return None

# Create a set of years to keep
years_to_keep = {'2023', '2024'}

# Filter columns to keep only those starting with the specified years
columns_for_years = [col for col in home_df.columns if extract_year_from_column(col) in years_to_keep]

# Combine the columns to keep
all_columns_to_keep = list(columns_to_keep) + columns_for_years

# Filter DataFrame
home_df_filtered = home_df[all_columns_to_keep]
home_df_filtered
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName     2023-01-31  \
# 0      102001         0    United States    country       NaN  346404.924992
# 1      394913         1     New York, NY        msa        NY  630167.338876
# 2      753899         2  Los Angeles, CA        msa        CA  934837.128995
# 3      394463         3      Chicago, IL        msa        IL  311951.545605
# 4      394514         4       Dallas, TX        msa        TX  381385.038358
# ..        ...       ...              ...        ...       ...            ...
# 890    753929       935       Zapata, TX        msa        TX  131700.475880
# 891    394743       936    Ketchikan, AK        msa        AK  440352.918670
# 892    753874       937        Craig, CO        msa        CO  272512.913242
# 893    395188       938       Vernon, TX        msa        TX   98318.432899
# 894    394767       939       Lamesa, TX        msa        TX  109400.971160
#
#         2023-02-28     2023-03-31     2023-04-30     2023-05-31  ...  \
# 0    345570.861280  345613.577117  346691.188602  348427.543021  ...
# 1    629689.056433  630846.093580  633668.487396  638326.217830  ...
# 2    923197.606579  912800.969373  910445.274641  914842.336079  ...
# 3    312048.560612  312957.110344  314879.540011  317202.480876  ...
# 4    379078.052729  377513.333757  376966.644414  377273.255286  ...
# ..             ...            ...            ...            ...  ...
# 890  128768.546619  127730.465336  127953.466165  127441.564783  ...
# 891  438006.940722  435122.242409  433701.247829  433950.968387  ...
# 892  273874.043683  275122.028970  277282.290613  280085.487600  ...
# 893   97243.204942   98476.486651  100112.568438  101491.316487  ...
# 894  107788.978895  107633.317925  107393.278709  107310.018413  ...
#
#         2023-10-31     2023-11-30     2023-12-31     2024-01-31  \
# 0    355986.448327  356640.365507  357118.576760  357576.035711
# 1    656116.650291  658992.330717  662322.088290  665541.460972
# 2    978656.081035  988006.132016  993962.586203  994044.629696
# 3    328270.794339  329219.545752  329991.513159  330838.545303
# 4    380533.777024  380382.508383  380056.886976  380085.827764
# ..             ...            ...            ...            ...
# 890  124547.031380  122338.760387  120284.544997  118569.499840
# 891  430162.304681  426865.266476  423965.648960  423457.606149
# 892  291672.198531  292412.687064  292344.802219  291552.668152
# 893   97651.281511   96117.960519   94767.283797   94062.082438
# 894   98553.321910   97646.633846   96196.584694   95403.020805
#
#         2024-02-29     2024-03-31     2024-04-30    2024-05-31    2024-06-30  \
# 0    358418.372959  360011.602927  361969.362164  3.635033e+05  3.641659e+05
# 1    669925.455906  675684.524493  682290.159549  6.873056e+05  6.905686e+05
# 2    990763.189872  989599.749912  993777.833894  1.000601e+06  1.005222e+06
# 3    332482.161364  335195.288195  338356.149580  3.407269e+05  3.421063e+05
# 4    380580.411239  381762.207346  382759.281581  3.829150e+05  3.822440e+05
# ..             ...            ...            ...           ...           ...
# 890  117733.766672  117811.796274  119242.025068  1.208697e+05  1.218988e+05
# 891  423400.547313  425166.352814  426865.782342  4.281101e+05  4.280975e+05
# 892  291483.099905  291958.734641  292753.813872  2.936681e+05  2.940164e+05
# 893   94161.423281   94877.489624   95666.336569  9.634301e+04  9.659689e+04
# 894   94204.376428   94247.953608   94473.532219  9.546670e+04  9.685846e+04
#
#        2024-07-31
# 0    3.643848e+05
# 1    6.932481e+05
# 2    1.010107e+06
# 3    3.429366e+05
# 4    3.812958e+05
# ..            ...
# 890  1.220752e+05
# 891  4.271596e+05
# 892  2.943587e+05
# 893  9.634983e+04
# 894  9.883584e+04
#
# [895 rows x 24 columns]

# %%
# Does state with higher the GDP have a difference in housing prices compare to states with lower GDP?
df_sorted = home_df_filtered.sort_values(by='StateName')
df_sorted.drop(['RegionType', 'SizeRank', 'RegionID'], axis = 1, inplace = True)
# List of columns to keep
columns_to_keep = ['RegionName', 'StateName', '2023-12-31']

# Filter the DataFrame to keep only the selected columns
df_filtered = df_sorted[columns_to_keep]
states = ['AZ','CA','TX','NY','HI','NV', 'FL', 'OR', 'WA', 'UT']
df_filtered = df_filtered[df_filtered['StateName'].isin(states)]
df_filtered = df_filtered.rename(columns={'2023-12-31': 'Prices in 2023'})
df_filtered = df_filtered.groupby('StateName')['Prices in 2023'].mean().reset_index()
df_filtered.head()
# Out:
#   StateName  Prices in 2023
# 0        AZ   364570.788844
# 1        CA   623747.259609
# 2        FL   380005.446124
# 3        HI   917894.472719
# 4        NV   428171.199827

# %%
gdp_df = pd.read_csv('../Source/GDP_2023.csv')
gdp_states = ['Arizona', 'California', 'Texas', 'New York', 'Hawaii', 'Nevada', 'Florida', 'Oregon', 'Washington', 'Utah']
gdp_df = gdp_df[gdp_df['GeoName'].isin(gdp_states)]
gdp_df.drop('GeoFips', axis = 1, inplace = True)
gdp_df = gdp_df.rename(columns={'GeoName': 'StateName'})
gdp_df = gdp_df.rename(columns={'2023': 'GDP 2023'})
gdp_df.head(10)
# Out:
#      StateName   GDP 2023
# 3      Arizona   414273.3
# 5   California  3233151.0
# 10     Florida  1279118.8
# 12      Hawaii    86887.7
# 29      Nevada   192215.6
# 33    New York  1775714.1
# 38      Oregon   260110.8
# 44       Texas  2032932.9
# 45        Utah   219180.7
# 48  Washington   672125.3

# %%
# gdp_df = pd.read_csv('../Source/GDP_2022.csv')
# gdp_df.head()

# %%
state_mapping = {
    'Arizona': 'AZ',
    'California': 'CA',
    'Texas': 'TX',
    'New York': 'NY',
    'Hawaii': 'HI',
    'Nevada': 'NV',
    'Florida': 'FL',
    'Oregon': 'OR',
    'Washington': 'WA',
    'Utah': 'UT'
}

gdp_df['StateName'] = gdp_df['StateName'].map(state_mapping)
merged_df = pd.merge(df_filtered, gdp_df, on='StateName')
df_sorted_gdp = merged_df.sort_values(by='GDP 2023')
df_sorted_gdp.head(10)
# Out:
#   StateName  Prices in 2023   GDP 2023
# 3        HI   917894.472719    86887.7
# 4        NV   428171.199827   192215.6
# 8        UT   527233.669631   219180.7
# 6        OR   445341.676998   260110.8
# 0        AZ   364570.788844   414273.3
# 9        WA   471724.370376   672125.3
# 2        FL   380005.446124  1279118.8
# 5        NY   239027.322606  1775714.1
# 7        TX   213950.286886  2032932.9
# 1        CA   623747.259609  3233151.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for seaborn
sns.set(style="whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(2, 1, figsize=(10, 12), sharex=True)

# Plot the bar graph for State vs. Prices
sns.barplot(x='StateName', y='Prices in 2023', data=merged_df, ax=axes[0], palette="Blues_d")
axes[0].set_title('State vs. Prices in 2023')
axes[0].set_ylabel('Prices in 2023')

# # Plot the bar graph for State vs. GDP
sns.barplot(x='StateName', y='GDP 2023', data=merged_df, ax=axes[1], palette="Greens_d")
axes[1].set_title('State vs. GDP in 2023')
axes[1].set_ylabel('GDP in 2023')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()

# %%
df_sorted_gdp
# Out:
#   StateName  Prices in 2023   GDP 2023
# 3        HI   917894.472719    86887.7
# 4        NV   428171.199827   192215.6
# 8        UT   527233.669631   219180.7
# 6        OR   445341.676998   260110.8
# 0        AZ   364570.788844   414273.3
# 9        WA   471724.370376   672125.3
# 2        FL   380005.446124  1279118.8
# 5        NY   239027.322606  1775714.1
# 7        TX   213950.286886  2032932.9
# 1        CA   623747.259609  3233151.0
