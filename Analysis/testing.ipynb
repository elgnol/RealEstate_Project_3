# %%
import pandas as pd

# %%
home_df = pd.read_csv('../SOURCE/filtered_home_df.csv')

# %%
home_df
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName     2015-01-31  \
# 0      102001         0    United States    country       USA  188211.155261
# 1      394299       251      Abilene, TX        msa        TX  116800.595050
# 2      394304        83        Akron, OH        msa        OH  120102.163828
# 3      394308        64       Albany, NY        msa        NY  202239.261415
# 4      394312        62  Albuquerque, NM        msa        NM  173035.342285
# ..        ...       ...              ...        ...       ...            ...
# 159    395224        94      Wichita, KS        msa        KS  117721.189468
# 160    395229       174   Wilmington, NC        msa        NC  211817.752815
# 161    395232       308   Winchester, VA        msa        VA  207509.272554
# 162    395235        89      Winston, NC        msa        NC  138393.777698
# 163    395244       122         York, PA        msa        PA  162653.903760
#
# ...
